# %% [markdown]
# ## ADP - Neural Network Value Function
#
# In this Notebook we implemented the ADP algorithm using neural network as value function. Distributions of demand in each location is either normal or poisson.
#
# Code is documented with comments and markdown blocks.

# %%
# dependencies
import random
import numpy as np
import pandas as pd
import gurobipy as gp
from gurobipy import *
import tensorflow as tf
from tensorflow import keras

# %%
# sets
locations = 2
periods = 10

# initial state
initialInventory = [70, 70] # initial inventory
total_bikes = sum(initialInventory)

# extrogenous info
demandMean = [50, 90]

# %%
def poisson(mean, lambd):
    return round(mean + np.random.poisson(lambd, 1)[0])

def normal(mean, std):
    return round(np.random.normal(mean, std, 1)[0])

# %% [markdown]
# ### Optimal Action Linear Program
#
# The following function defines a Linear Program for finding the best action in the problem. Action space is very high: shifting one bike from location i to j, shifting two bikes from location j to k etc... All of those combinations can be seen as different actions, depending also on the inventory levels.

# %%
"""
locations: number of locations
holding_cost: array containing the holding cost per unit in each location
trans_cost: matrix with the cost for moving one unit from a location to another one
inventory: array with current state (number of bikes per location), each value represent one location
total_bikes: total number of bikes in the network
shiftable_bikes: array containing the number of bikes that can be shifted (if positive) or taken (if negative) from/in a location
env: gurobipy configuration
"""
def best_action(locations, holding_cost, penalty_cost, trans_cost, inventory, total_bikes, shiftable_bikes, env=None):
    demands = []
    for i in range(locations):
        demands.append(inventory[i] - shiftable_bikes[i])
    print("demands"+str(demands))
    print("inventory"+str(inventory))

    lp = gp.Model("Transshipment Decision Linear Programming", env=env)
    y = {} # number of bikes at each location after transshipment inventory
    z = {} # transshipment decision
    l = {} # linearize penalty_cost
    h = {} # linearize holding_cost
    for i in range(locations):
        y[i] = lp.addVar(lb=0, vtype=GRB.INTEGER)
        l[i] = lp.addVar()
        h[i] = lp.addVar()
    for i in range(locations):
        for j in range(locations):
            z[i,j] = lp.addVar(lb=0, vtype=GRB.INTEGER)
    
    # preserve costant number of bikes if we sum all locations # capacity constraint
    lp.addConstr(sum(y[i] for i in range(locations)) == total_bikes)

    # transshipment decision
    for i in range(locations):
        lp.addConstr(y[i] == inventory[i] + sum(z[j,i] - z[i,j] for j in range(locations)))

    # transshipment amount=inventory at retailer i at time t
    for i in range(locations):
        lp.addConstr(sum(z[i,j] for j in range(locations)) == inventory[i])
    
    # linearize penalty_cost: max(0, d[i]-y[i])
    for i in range(locations):
        lp.addConstr(l[i] >= 0)
        lp.addConstr(l[i] >= float(demands[i]) - y[i])
    
    # linearize holding_cost: max(0, y[i]-d[i])
    for i in range(locations):
        lp.addConstr(h[i] >= 0)
        lp.addConstr(h[i] >= y[i] - demands[i])
     
    obj = sum(trans_cost[i][j]*z[i,j] for i in range(locations) for j in range(locations)) + sum(penalty_cost[i]*l[i] + holding_cost[i]*h[i] for i in range(locations))
    lp.setObjective(obj, GRB.MINIMIZE)
    lp.optimize()
    
    solution_z = lp.getAttr('x', z)
    for i in range(locations):
        for j in range(locations):
            if solution_z[i,j] > 0:
                print ('%s -> %s ship: %g' % (i,j,solution_z[i,j]))

    z = []
    for i in range(locations):
        z.append([])
        for j in range(locations):
            z[i].append(solution_z[i,j])

    return lp.objVal, z

# %% [markdown]
# ### Neural Network Value Function
#
# Value function is this case is represented by a Neural Network model. Hence, data is encoded into a weight and a bias. Input is the demand and it tries to predict how many bikes can be shifted from each location. We initialize one model for each location so that it can be easier handling different distributions of the demand.
#
# Technically speaking, we train the weights with the well known Mean Least Squares approach and Stochastic Gradient Descent using the Tensorflow library.
#
# The main function in the following block represents the update of the weights that is called at each iteration of the ADP algorithm.
#
# We used different regularizing techniques, such a L2 regularizer, a dropout layer, to avoid overfittting, paritcularly at the initial periods where we have litte data to train. Also, we used learning rates and momentums to help escape from local minimum and find global minimum.

# %%
def nn(available_bikes, demand, inventory_nr, locations): #classifier
    train_X, train_Y = [], []
    for i in range(len(available_bikes) - 1):
        train_X.append([available_bikes[i][inventory_nr]])
        train_Y.append([demand[i+1][inventory_nr] - available_bikes[i][inventory_nr]]) # shiftable bikes

    train_X = np.array(train_X)
    train_Y = np.array(train_Y)
    
    model = keras.Sequential([
    keras.layers.Dense(units = locations^3, 
                       activation='relu',
                       kernel_regularizer=keras.regularizers.l2(0.1),
                       input_shape=(train_X.shape[-1],)),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(1, activation='linear')])

    model.compile(
        optimizer=keras.optimizers.SGD(learning_rate=0.0001, momentum=0.3),
        loss=keras.losses.MeanSquaredError(),
        metrics=[keras.metrics.MeanSquaredError(name='mean_squared_error')])
    
    history = model.fit(x=train_X, 
                        y=train_Y,
                        epochs=5, 
                        batch_size=10,
                        shuffle = True,
                        verbose=0)
    
    MSE = history.history['mean_squared_error'][-1]
    
    return model, MSE

def init_linear_model():
    weights = np.random.randn(1, 1) / 4
    bias = np.random.randn(1, 1) / 4

    return [weights, bias]


"""
available_bikes: number of bikes at a specific location
"""
def predict_shiftable_demand(weights, bias, available_bikes):
    return weights * available_bikes + bias

# %% [markdown]
# ### Approximate Dynamic Programming
#
# As seen during the lecture, the main logic of ADP is contained into the main loop which has three phases:
# - Make a decision
# - Update the value function
# - Determine next observation state
#
# This is exactly what the snippet below is doing. For the action part, we rely on the Linear Program seen before. The decision is always taken: this should be interpreted as if we have a transition probability equals to 1 for the chosen action. In our bike sharing scenario we can translate it with "bikes are always shifted according to the plan" (trucks never break etc...). In the Linear Program we also input the output of the value function.
#
# Value function is updated accordinly to the model we use. For moving average, we can just add the new observation to a vector and last N values can be used for calculating the value. For linear regression and neural network, we use stochastic gradient descent. That way, we can handle training (read updating) in an online fashion easily.
#
# For updating the observation space for the next iteration, we just need to apply transshipment decision retrieved from the Linear Program.
#
# As far as the running average is concerned, the implementation simply keeps each observation in a specific array and computes the mean when needed.

# %%
def ADP(locations, periods, holding_cost, penalty_cost, trans_cost, initialInventory, demand_dist, demandMean, demandPara, total_bikes):
    # initialize post-decison value function approximation
    costs = []      
    # initialize after transshipment inventory per location per period
    y = []
    # initialize transshipment decision per location per period
    z = [[[None]*locations for _ in range(locations)] for _ in range(periods)] 
    # before transshipment inventory x_it at x_i0 = S_i
    inventory = []
    inventory.append(initialInventory)
    # initialize demands
    demands = []
        
    linear_models = []
    for _ in range(locations):
        linear_models.append(init_linear_model())
        
    ls_err_history = []
        
    for t in range(periods):
        # 1. calculate new demands for current day
        if demand_dist == "normal":
            demands.append([normal(demandMean[i], demandPara[i]) for i in range(locations)])
        elif demand_dist == "poisson":
            demands.append([poisson(demandMean[i], demandPara[i]) for i in range(locations)])
            
        # 2. make a decision - predict shiftable + linear model for best shift of bikes + calculate cost
        if t <= 1: # simple linear regression used for the first two iterations until nn model is built in the 3rd period
            shiftable_bikes = []
            for i in range(locations):
                shiftable_bikes.append(predict_shiftable_demand(linear_models[i][0], linear_models[i][1], inventory[t][i]))
        else: # neural network 
            shiftable_bikes = []
            for i in range(locations):
                shiftable_bikes.append(linear_models[i].predict([inventory[t][i]]))
            
        print("shiftable_bikes"+str(shiftable_bikes))
        
        # linear program: calcualte cost and decision
        value, z_t = best_action(locations, holding_cost, penalty_cost, trans_cost, inventory[t], total_bikes, shiftable_bikes, env=None)
        costs.append(value)
        for i in range(locations):
            for j in range(locations):
                z[t][i][j] = z_t[i][j]
            
        # 3. update value function approximation
        errs = []
        if t > 0:
            for i in range(locations):
                estimator, err = nn(inventory, demands, i, locations)
                linear_models[i] = estimator
                errs.append(err)
            ls_err_history.append(err) 
            
        # 4. make transshipment decision to determine the next state
        new_inventory = [inventory[t][i] + sum(z[t][j][i] -z[t][i][j] for j in range(locations)) for i in range(locations)]
        inventory.append(new_inventory)
                
    return sum(costs)/periods

# %% [markdown]
# ### Performances
# The table below represents the average cost per period, which varies in different setting of cost and demand parameters. We expect to see the model can help predict cost consistently even if the variation of demand becomes larger. However, the model fails to do so.

# %%
# cost parameters
holding_cost = [[2, 2]] # per location i
penalty_cost = [[2, 2], [4, 4]] # per location i
trans_cost = [[[0, 1],[1, 0]],[[0, 1],[3, 0]]] # from i to j

# demand parameters
std_demands = [[5, 5], [10, 10]]
delta_demands = [[1, 1], [2, 2]]
demand_dist = {"normal":std_demands, "poisson":delta_demands}

perform_dict = {}
n=0
for holdingcost in holding_cost:
    for penaltycost in penalty_cost:
        for transcost in trans_cost:
            for demanddist, i in demand_dist.items():
                for demandpara in i:
                    cost = ADP(locations,periods,holdingcost,penaltycost,transcost,initialInventory,demanddist,demandMean,demandpara,total_bikes)
                    perform_dict[n]=[penaltycost[0],transcost,demanddist,demandpara[0],cost]
                    n+=1

summary_performance = pd.DataFrame.from_dict(perform_dict, orient = 'index', columns = ['penalty cost','transportation cost', 'demand distribution', 'demand parameters', 'Objective'])
summary_performance
# Out:
# shiftable_bikes[array([[1.85308842]]), array([[3.90899345]])]
# demands[array([[68.14691158]]), array([[66.09100655]])]
# inventory[70, 70]
# Academic license - for non-commercial use only - expires 2021-09-05
# Using license file /Users/mingyutu/gurobi.lic
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x2ed53e4e
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 1.152416e+01, 0 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      11.5241637   11.52416  0.00%     -    0s
#
# Explored 0 nodes (0 simplex iterations) in 0.12 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 11.5242
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.152416374433e+01, best bound 1.152416374433e+01, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
# shiftable_bikes[array([[1.85308842]]), array([[3.90899345]])]
# demands[array([[68.14691158]]), array([[66.09100655]])]
# inventory[70.0, 70.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x2ed53e4e
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 1.152416e+01, 0 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      11.5241637   11.52416  0.00%     -    0s
#
# Explored 0 nodes (0 simplex iterations) in 0.05 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 11.5242
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.152416374433e+01, best bound 1.152416374433e+01, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
# shiftable_bikes[array([[-0.01958759]], dtype=float32), array([[0.0505345]], dtype=float32)]
# demands[array([[70.019585]], dtype=float32), array([[69.94946]], dtype=float32)]
# inventory[70.0, 70.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x692c3fbd
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 8.148956e-02, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.08149    0    1          -    0.08149      -     -    0s
# H    0     0                       0.1402435    0.08149  41.9%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.13 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.140244
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.402435302734e-01, best bound 1.402435302731e-01, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
# shiftable_bikes[array([[-0.02546387]], dtype=float32), array([[0.03134014]], dtype=float32)]
# demands[array([[70.02547]], dtype=float32), array([[69.96866]], dtype=float32)]
# inventory[70.0, 70.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0xf0495da5
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 3.721619e-02, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.03722    0    1          -    0.03722      -     -    0s
# H    0     0                       0.1136169    0.03722  67.2%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.12 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.113617
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.136169433594e-01, best bound 1.136169433590e-01, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe209a1a830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe209f07a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# shiftable_bikes[array([[-0.02916375]], dtype=float32), array([[21.206585]], dtype=float32)]
# demands[array([[70.02917]], dtype=float32), array([[48.793415]], dtype=float32)]
# inventory[70.0, 70.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x9bcc3bfe
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 4.238400e+01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   42.38400    0    1          -   42.38400      -     -    0s
# H    0     0                      42.4715042   42.38400  0.21%     -    0s
# Explored 1 nodes (1 simplex iterations) in 0.11 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 42.4715
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.247150421143e+01, best bound 4.247150421143e+01, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
# shiftable_bikes[array([[-0.05351914]], dtype=float32), array([[0.03804676]], dtype=float32)]
# demands[array([[70.05352]], dtype=float32), array([[69.96195]], dtype=float32)]
# inventory[70.0, 70.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x5db7b1d0
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 6.899261e-02, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.06899    0    1          -    0.06899      -     -    0s
# H    0     0                       0.1831360    0.06899  62.3%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.17 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.183136
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.831359863281e-01, best bound 1.831359863278e-01, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
# shiftable_bikes[array([[-0.06487416]], dtype=float32), array([[0.0284673]], dtype=float32)]
# demands[array([[70.06487]], dtype=float32), array([[69.971535]], dtype=float32)]
# inventory[70.0, 70.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x86868cf6
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 1.012802e-01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.10128    0    1          -    0.10128      -     -    0s
# H    0     0                       0.1866760    0.10128  45.7%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.16 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.186676
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.866760253906e-01, best bound 1.866760253903e-01, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
# shiftable_bikes[array([[-0.02872847]], dtype=float32), array([[0.02873556]], dtype=float32)]
# demands[array([[70.028725]], dtype=float32), array([[69.97127]], dtype=float32)]
# inventory[70.0, 70.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0xa930701f
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 2.873993e-02, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.02874    0    1          -    0.02874      -     -    0s
# H    0     0                       0.1149139    0.02874  75.0%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.04 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.114914
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.149139404297e-01, best bound 1.149139404293e-01, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
# shiftable_bikes[array([[-20.569746]], dtype=float32), array([[0.02816882]], dtype=float32)]
# demands[array([[90.56975]], dtype=float32), array([[69.97183]], dtype=float32)]
# inventory[70.0, 70.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0xdf6408a5
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 4.111133e+01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   41.11133    0    1          -   41.11133      -     -    0s
# H    0     0                      41.1958313   41.11133  0.21%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.10 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 41.1958
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.119583129883e+01, best bound 4.119583129883e+01, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
# shiftable_bikes[array([[-0.02693294]], dtype=float32), array([[0.03486018]], dtype=float32)]
# demands[array([[70.02693]], dtype=float32), array([[69.96514]], dtype=float32)]
# inventory[70.0, 70.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x26825577
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 4.278564e-02, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.04279    0    1          -    0.04279      -     -    0s
# H    0     0                       0.1235809    0.04279  65.4%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.12 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.123581
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.235809326172e-01, best bound 1.235809326168e-01, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
# shiftable_bikes[array([[24.38390777]]), array([[-34.18575483]])]
# demands[array([[45.61609223]]), array([[104.18575483]])]
# inventory[70, 70]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x6185d82b
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 4.398760e+01, 1 iterations, 0.00 seconds
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   43.98760    0    1          -   43.98760      -     -    0s
# H    0     0                     117.1393252   43.98760  62.4%     -    0s
# H    0     0                      45.1393252   43.98760  2.55%     -    0s
# *    0     0               0      44.6036941   44.60369  0.00%     -    0s
#
# Cutting planes:
#   MIR: 1
#
# Explored 1 nodes (2 simplex iterations) in 0.06 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 44.6037 45.1393 117.139
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.460369410857e+01, best bound 4.460369410857e+01, gap 0.0000%
# 0 -> 0 ship: 45
# 0 -> 1 ship: 25
# 1 -> 1 ship: 70
# shiftable_bikes[array([[15.64103004]]), array([[-46.41400785]])]
# demands[array([[29.35896996]]), array([[141.41400785]])]
# inventory[45.0, 95.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0xc5207cf4
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+01, 1e+02]
# Presolve removed 12 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 4 columns, 4 nonzeros
# Variable types: 2 continuous, 2 integer (0 binary)
# Found heuristic solution: objective 106.5459556
#
# Root relaxation: objective 7.718699e+01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   77.18699    0    1  106.54596   77.18699  27.6%     -    0s
# H    0     0                      77.5459556   77.18699  0.46%     -    0s
#      0     0   77.18699    0    1   77.54596   77.18699  0.46%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.03 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 77.546 106.546
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.754595562832e+01, best bound 7.754595562832e+01, gap 0.0000%
# 0 -> 0 ship: 29
# 0 -> 1 ship: 16
# 1 -> 1 ship: 95
# shiftable_bikes[array([[-0.03512946]], dtype=float32), array([[0.]], dtype=float32)]
# demands[array([[29.03513]], dtype=float32), array([[111.]], dtype=float32)]
# inventory[29.0, 111.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0xd78b4142
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 7.025909e-02, 0 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.0702591    0.07026  0.00%     -    0s
#
# Explored 0 nodes (0 simplex iterations) in 0.06 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.0702591
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.025909423828e-02, best bound 7.025909423828e-02, gap 0.0000%
# 0 -> 0 ship: 29
# 1 -> 1 ship: 111
# shiftable_bikes[array([[-0.03586391]], dtype=float32), array([[-0.03975302]], dtype=float32)]
# demands[array([[29.035864]], dtype=float32), array([[111.03976]], dtype=float32)]
# inventory[29.0, 111.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x7750be7b
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 1.512413e-01, 0 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.1512413    0.15124  0.00%     -    0s
#
# Explored 0 nodes (0 simplex iterations) in 0.07 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.151241
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.512413024902e-01, best bound 1.512413024902e-01, gap 0.0000%
# 0 -> 0 ship: 29
# 1 -> 1 ship: 111
# shiftable_bikes[array([[0.00478808]], dtype=float32), array([[0.02614396]], dtype=float32)]
# demands[array([[28.995213]], dtype=float32), array([[110.973854]], dtype=float32)]
# inventory[29.0, 111.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x2bf0e565
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 6.186676e-02, 0 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.0618668    0.06187  0.00%     -    0s
#
# Explored 0 nodes (0 simplex iterations) in 0.09 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.0618668
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.186676025391e-02, best bound 6.186676025391e-02, gap 0.0000%
# 0 -> 0 ship: 29
# 1 -> 1 ship: 111
# shiftable_bikes[array([[4.654899]], dtype=float32), array([[-0.00979379]], dtype=float32)]
# demands[array([[24.3451]], dtype=float32), array([[111.009796]], dtype=float32)]
# inventory[29.0, 111.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0xc4e5abe5
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 9.300003e+00, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    9.30000    0    1          -    9.30000      -     -    0s
# H    0     0                       9.3293915    9.30000  0.32%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.08 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 9.32939
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.329391479492e+00, best bound 9.329391479492e+00, gap 0.0000%
# 0 -> 0 ship: 29
# 1 -> 1 ship: 111
# shiftable_bikes[array([[0.03566896]], dtype=float32), array([[-0.01167516]], dtype=float32)]
# demands[array([[28.96433]], dtype=float32), array([[111.01167]], dtype=float32)]
# inventory[29.0, 111.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x69fcf86e
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 5.966568e-02, 1 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.05967    0    1          -    0.05967      -     -    0s
# H    0     0                       0.0946846    0.05967  37.0%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.11 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.0946846
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.468460083008e-02, best bound 9.468460082962e-02, gap 0.0000%
# 0 -> 0 ship: 29
# 1 -> 1 ship: 111
# shiftable_bikes[array([[0.00261168]], dtype=float32), array([[-0.01289112]], dtype=float32)]
# demands[array([[28.997389]], dtype=float32), array([[111.01289]], dtype=float32)]
# inventory[29.0, 111.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0xfe1a76d2
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 2.317619e-02, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.02318    0    1          -    0.02318      -     -    0s
# H    0     0                       0.0310097    0.02318  25.3%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.05 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.0310097
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.100967407227e-02, best bound 3.100967407181e-02, gap 0.0000%
# 0 -> 0 ship: 29
# 1 -> 1 ship: 111
# shiftable_bikes[array([[0.01678936]], dtype=float32), array([[-0.0123122]], dtype=float32)]
# demands[array([[28.983212]], dtype=float32), array([[111.012314]], dtype=float32)]
# inventory[29.0, 111.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0xc0079e56
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 2.126312e-02, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.02126    0    1          -    0.02126      -     -    0s
# H    0     0                       0.0582047    0.02126  63.5%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.19 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.0582047
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.820465087891e-02, best bound 5.820465087845e-02, gap 0.0000%
# 0 -> 0 ship: 29
# 1 -> 1 ship: 111
# shiftable_bikes[array([[0.01681268]], dtype=float32), array([[-0.02267109]], dtype=float32)]
# demands[array([[28.983187]], dtype=float32), array([[111.022675]], dtype=float32)]
# inventory[29.0, 111.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x4e4c994b
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 2.853584e-02, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.02854    0    1          -    0.02854      -     -    0s
# H    0     0                       0.0789757    0.02854  63.9%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.10 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.0789757
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.897567749023e-02, best bound 7.897567748978e-02, gap 0.0000%
# 0 -> 0 ship: 29
# 1 -> 1 ship: 111
# shiftable_bikes[array([[7.22774822]]), array([[-20.91508898]])]
# demands[array([[62.77225178]]), array([[90.91508898]])]
# inventory[70, 70]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x9ce3f544
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 3.460243e+01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   34.60243    0    1          -   34.60243      -     -    0s
# H    0     0                      56.2856744   34.60243  38.5%     -    0s
# H    0     0                      35.2856744   34.60243  1.94%     -    0s
#      0     0   34.60243    0    1   35.28567   34.60243  1.94%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.25 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 35.2857 56.2857
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.528567439411e+01, best bound 3.528567439411e+01, gap 0.0000%
# 0 -> 0 ship: 63
# 0 -> 1 ship: 7
# 1 -> 1 ship: 70
# shiftable_bikes[array([[6.49650209]]), array([[-22.99880736]])]
# demands[array([[56.50349791]]), array([[99.99880736]])]
# inventory[63.0, 77.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x71b9f8c6
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 3.950111e+01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   39.50111    0    1          -   39.50111      -     -    0s
# H    0     0                      58.9906189   39.50111  33.0%     -    0s
# H    0     0                      40.9906189   39.50111  3.63%     -    0s
# *    0     0               0      40.0046105   40.00461  0.00%     -    0s
#
# Cutting planes:
#   MIR: 1
# Explored 1 nodes (2 simplex iterations) in 0.05 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 40.0046 40.9906 58.9906
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000461053821e+01, best bound 4.000461053821e+01, gap 0.0000%
# 0 -> 0 ship: 56
# 0 -> 1 ship: 7
# 1 -> 1 ship: 77
# shiftable_bikes[array([[-0.02611679]], dtype=float32), array([[0.02742263]], dtype=float32)]
# demands[array([[56.026115]], dtype=float32), array([[83.97258]], dtype=float32)]
# inventory[56.0, 84.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x3313707a
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 2.872467e-02, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.02872    0    1          -    0.02872      -     -    0s
# H    0     0                       0.1070709    0.02872  73.2%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.05 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.107071
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.070709228516e-01, best bound 1.070709228513e-01, gap 0.0000%
# 0 -> 0 ship: 56
# 1 -> 1 ship: 84
# shiftable_bikes[array([[-10.80136]], dtype=float32), array([[0.31057215]], dtype=float32)]
# demands[array([[66.80136]], dtype=float32), array([[83.68943]], dtype=float32)]
# inventory[56.0, 84.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x7372c053
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 2.129215e+01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   21.29215    0    1          -   21.29215      -     -    0s
# H    0     0                      22.2238617   21.29215  4.19%     -    0s
# *    0     0               0      21.9815826   21.98158  0.00%     -    0s
#
# Cutting planes:
#   MIR: 1
#
# Explored 1 nodes (2 simplex iterations) in 0.08 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 21.9816 22.2239
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.198158264160e+01, best bound 2.198158264160e+01, gap 0.0000%
# 0 -> 0 ship: 56
# 1 -> 0 ship: 1
# 1 -> 1 ship: 83
# shiftable_bikes[array([[-0.01479951]], dtype=float32), array([[0.01828175]], dtype=float32)]
# demands[array([[57.0148]], dtype=float32), array([[82.98172]], dtype=float32)]
# inventory[57.0, 83.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x806790c6
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 2.175903e-02, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.02176    0    1          -    0.02176      -     -    0s
# H    0     0                       0.0661621    0.02176  67.1%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.10 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.0661621
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.616210937500e-02, best bound 6.616210937477e-02, gap 0.0000%
# 0 -> 0 ship: 57
# 1 -> 1 ship: 83
# shiftable_bikes[array([[-0.03591469]], dtype=float32), array([[0.01599653]], dtype=float32)]
# demands[array([[57.035915]], dtype=float32), array([[82.984]], dtype=float32)]
# inventory[57.0, 83.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0xe91b7576
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 5.583191e-02, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.05583    0    1          -    0.05583      -     -    0s
# H    0     0                       0.1038284    0.05583  46.2%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.07 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.103828
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.038284301758e-01, best bound 1.038284301756e-01, gap 0.0000%
# 0 -> 0 ship: 57
# 1 -> 1 ship: 83
# shiftable_bikes[array([[-0.05013651]], dtype=float32), array([[0.05557224]], dtype=float32)]
# demands[array([[57.050137]], dtype=float32), array([[82.94443]], dtype=float32)]
# inventory[57.0, 83.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x17edfbbc
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 6.100845e-02, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.06101    0    1          -    0.06101      -     -    0s
# H    0     0                       0.2114182    0.06101  71.1%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.07 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.211418
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.114181518555e-01, best bound 2.114181518552e-01, gap 0.0000%
# 0 -> 0 ship: 57
# 1 -> 1 ship: 83
# shiftable_bikes[array([[-0.01109964]], dtype=float32), array([[0.00665325]], dtype=float32)]
# demands[array([[57.0111]], dtype=float32), array([[82.99335]], dtype=float32)]
# inventory[57.0, 83.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0xdda1984a
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 1.554871e-02, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.01555    0    1          -    0.01555      -     -    0s
# H    0     0                       0.0355072    0.01555  56.2%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.12 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.0355072
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.550720214844e-02, best bound 3.550720214821e-02, gap 0.0000%
# 0 -> 0 ship: 57
# 1 -> 1 ship: 83
# shiftable_bikes[array([[-5.866221]], dtype=float32), array([[0.02331611]], dtype=float32)]
# demands[array([[62.866222]], dtype=float32), array([[82.976685]], dtype=float32)]
# inventory[57.0, 83.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0xe8a20235
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 1.170913e+01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   11.70913    0    1          -   11.70913      -     -    0s
# H    0     0                      11.7790756   11.70913  0.59%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.17 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 11.7791
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.177907562256e+01, best bound 1.177907562256e+01, gap 0.0000%
# 0 -> 0 ship: 57
# 1 -> 1 ship: 83
# shiftable_bikes[array([[-0.01028349]], dtype=float32), array([[0.02604254]], dtype=float32)]
# demands[array([[57.010284]], dtype=float32), array([[82.97396]], dtype=float32)]
# inventory[57.0, 83.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x31f6b167
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 4.179382e-02, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.04179    0    1          -    0.04179      -     -    0s
# H    0     0                       0.0726471    0.04179  42.5%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.10 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.0726471
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.264709472656e-02, best bound 7.264709472634e-02, gap 0.0000%
# 0 -> 0 ship: 57
# 1 -> 1 ship: 83
# shiftable_bikes[array([[19.67862325]]), array([[-3.72886227]])]
# demands[array([[50.32137675]]), array([[73.72886227]])]
# inventory[70, 70]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x8400a376
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 3.562838e+01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   35.62838    0    1          -   35.62838      -     -    0s
# H    0     0                      46.8149710   35.62838  23.9%     -    0s
# H    0     0                      35.8995219   35.62838  0.76%     -    0s
#      0     0   35.62838    0    1   35.89952   35.62838  0.76%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.12 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 35.8995 46.815
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.589952194844e+01, best bound 3.589952194844e+01, gap 0.0000%
# 0 -> 0 ship: 66
# 0 -> 1 ship: 4
# 1 -> 1 ship: 70
# shiftable_bikes[array([[18.53552937]]), array([[-3.93296857]])]
# demands[array([[47.46447063]]), array([[77.93296857]])]
# inventory[66.0, 74.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0xbb64b848
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 3.313809e+01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   33.13809    0    1          -   33.13809      -     -    0s
# H    0     0                      44.9369959   33.13809  26.3%     -    0s
# H    0     0                      33.2051216   33.13809  0.20%     -    0s
#      0     0   33.13809    0    1   33.20512   33.13809  0.20%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.05 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 33.2051 44.937
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.320512160043e+01, best bound 3.320512160043e+01, gap 0.0000%
# 0 -> 0 ship: 62
# 0 -> 1 ship: 4
# 1 -> 1 ship: 74
# ...
# H    0     0                      33.0429993   32.96809  0.23%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.03 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 33.043
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.304299926758e+01, best bound 3.304299926758e+01, gap 0.0000%
# 0 -> 0 ship: 77
# 1 -> 1 ship: 63
# shiftable_bikes[array([[18.72134763]]), array([[35.00859193]])]
# demands[array([[51.27865237]]), array([[34.99140807]])]
# inventory[70, 70]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x24b04621
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 1.074599e+02, 0 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     107.4598791  107.45988  0.00%     -    0s
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 107.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.074598791242e+02, best bound 1.074598791242e+02, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
# shiftable_bikes[array([[18.72134763]]), array([[35.00859193]])]
# demands[array([[51.27865237]]), array([[34.99140807]])]
# inventory[70.0, 70.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x24b04621
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 1.074599e+02, 0 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     107.4598791  107.45988  0.00%     -    0s
#
# Explored 0 nodes (0 simplex iterations) in 0.10 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 107.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.074598791242e+02, best bound 1.074598791242e+02, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
# shiftable_bikes[array([[-0.0556149]], dtype=float32), array([[0.02872847]], dtype=float32)]
# demands[array([[70.05562]], dtype=float32), array([[69.971275]], dtype=float32)]
# inventory[70.0, 70.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0xac66146b
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 1.937485e-01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.19375    0    1          -    0.19375      -     -    0s
# H    0     0                       0.2799225    0.19375  30.8%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.03 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.279922
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.799224853516e-01, best bound 2.799224853511e-01, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
# shiftable_bikes[array([[-0.02481095]], dtype=float32), array([[0.0551635]], dtype=float32)]
# demands[array([[70.02481]], dtype=float32), array([[69.94484]], dtype=float32)]
# inventory[70.0, 70.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x12c76fa6
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 1.351318e-01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.13513    0    1          -    0.13513      -     -    0s
# H    0     0                       0.2095642    0.13513  35.5%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.03 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.209564
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.095642089844e-01, best bound 2.095642089839e-01, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
# shiftable_bikes[array([[-16.545975]], dtype=float32), array([[0.02916375]], dtype=float32)]
# demands[array([[86.545975]], dtype=float32), array([[69.97083]], dtype=float32)]
# inventory[70.0, 70.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x4cf1407e
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 6.615473e+01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   66.15473    0    1          -   66.15473      -     -    0s
# H    0     0                      66.2422333   66.15473  0.13%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.07 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 66.2422
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.624223327637e+01, best bound 6.624223327637e+01, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
# shiftable_bikes[array([[-0.02481095]], dtype=float32), array([[0.02872847]], dtype=float32)]
# demands[array([[70.02481]], dtype=float32), array([[69.971275]], dtype=float32)]
# inventory[70.0, 70.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x974d5a66
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 8.226013e-02, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.08226    0    1          -    0.08226      -     -    0s
# H    0     0                       0.1566925    0.08226  47.5%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.03 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.156693
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.566925048828e-01, best bound 1.566925048823e-01, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
# shiftable_bikes[array([[-0.02454978]], dtype=float32), array([[0.02820613]], dtype=float32)]
# demands[array([[70.02455]], dtype=float32), array([[69.971794]], dtype=float32)]
# inventory[70.0, 70.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x8e2d1181
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 8.096313e-02, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.08096    0    1          -    0.08096      -     -    0s
# H    0     0                       0.1546173    0.08096  47.6%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.06 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.154617
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.546173095703e-01, best bound 1.546173095698e-01, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
# shiftable_bikes[array([[0.00238149]], dtype=float32), array([[20.397377]], dtype=float32)]
# demands[array([[69.99762]], dtype=float32), array([[49.602623]], dtype=float32)]
# inventory[70.0, 70.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x428cc8a1
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 4.079951e+01, 0 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      40.7995148   40.79951  0.00%     -    0s
#
# Explored 0 nodes (0 simplex iterations) in 0.07 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 40.7995
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.079951477051e+01, best bound 4.079951477051e+01, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
# shiftable_bikes[array([[-0.04168443]], dtype=float32), array([[5.874802]], dtype=float32)]
# demands[array([[70.04169]], dtype=float32), array([[64.1252]], dtype=float32)]
# inventory[70.0, 70.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x2f765dc2
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 1.179129e+01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   11.79129    0    1          -   11.79129      -     -    0s
# H    0     0                      11.9163513   11.79129  1.05%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.10 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 11.9164
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.191635131836e+01, best bound 1.191635131836e+01, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
# shiftable_bikes[array([[-0.03324919]], dtype=float32), array([[21.339338]], dtype=float32)]
# demands[array([[70.03325]], dtype=float32), array([[48.66066]], dtype=float32)]
# inventory[70.0, 70.0]
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 13 rows, 10 columns and 24 nonzeros
# Model fingerprint: 0x2b61cc92
# Variable types: 4 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+01, 1e+02]
# Presolve removed 12 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
# Variable types: 3 continuous, 2 integer (0 binary)
#
# Root relaxation: objective 4.271193e+01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   42.71193    0    1          -   42.71193      -     -    0s
# H    0     0                      42.8116760   42.71193  0.23%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.15 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 42.8117
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.281167602539e+01, best bound 4.281167602539e+01, gap 0.0000%
# 0 -> 0 ship: 70
# 1 -> 1 ship: 70
#     penalty cost transportation cost demand distribution  demand parameters  \
# 0              2    [[0, 1], [1, 0]]              normal                  5
# 1              2    [[0, 1], [1, 0]]              normal                 10
# 2              2    [[0, 1], [1, 0]]             poisson                  1
# 3              2    [[0, 1], [1, 0]]             poisson                  2
# 4              2    [[0, 1], [3, 0]]              normal                  5
# 5              2    [[0, 1], [3, 0]]              normal                 10
# 6              2    [[0, 1], [3, 0]]             poisson                  1
# 7              2    [[0, 1], [3, 0]]             poisson                  2
# 8              4    [[0, 1], [1, 0]]              normal                  5
# 9              4    [[0, 1], [1, 0]]              normal                 10
# 10             4    [[0, 1], [1, 0]]             poisson                  1
# 11             4    [[0, 1], [1, 0]]             poisson                  2
# 12             4    [[0, 1], [3, 0]]              normal                  5
# 13             4    [[0, 1], [3, 0]]              normal                 10
# 14             4    [[0, 1], [3, 0]]             poisson                  1
# 15             4    [[0, 1], [3, 0]]             poisson                  2
#
#     Objective
# 0   10.757783
# 1   13.202528
# 2   10.964758
# 3   25.318037
# 4   34.501263
# 5   24.178539
# 6   18.842306
# 7   16.187084
# 8   34.219465
# 9   32.826304
# 10  26.926481
# 11  26.996760
# 12  25.309027
# 13  41.889394
# 14  40.287343
# 15  37.749033
